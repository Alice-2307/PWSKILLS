# %% [markdown]
# ## Functions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#   - A function is a block of reusable code that perform specific task. we can create a function using def and call him directly by name
#
#   example:
#
#        def add_number (a,b,c):
#            return a+b+c
#
#         print(add_number(2,3,5))
#         output: 10
#
#   A method is associated with an object bacically it is defined inside the class. if we want to use method we have to use "." (dot) to use in our code like
#   1. .append is a method
#   2. .remove is also a method.
#
# 2. Explain the concept of function arguments and parameters in Python.
#   - Parameters are the names that we write inside the function. We use them as a placeholder for values.
#   Argumetns are the actual value we give to those parameters when we call the function. Arguments is the value that we assigned to the function parameters
#
#   Examples:
#        def add_number (a,b,c):
#            return a+b+c
#
#        print(add_number(2,3,5))
#        output: 10
#
#   in this examples (a,b,c) are the parameters of the add_number function and (2,3,5) are the arguments means value that we assigned to the parameters.
#
# 3.  What are the different ways to define and call a function in Python?
#   - 1. we define function using def and call a function directly by name
#
#   example:
#
#         def welcome ():
#             print("Welcome Sir/Madam")
#
#         welcome()
#         output: Welcome Sir/Madam
#
#   2. using parameters and arguments
#
#            def welcome (name):
#                print("Welcome", name)
#
#            welcome("pwskills")
#            output: Welcome pwskills
#
#   3. using return statement
#
#            def add_number (a,b,c):
#               return a+b+c
#
#            print(add_number(2,3,5))
#            output: 10
#
#   4. with default parameters
#
#            def welcome(name="Sir/Madam"):
#                print("Welcome",name)
#
#            welcome("pwskills)
#            output: Welcome pwskills
#            welcome()
#            output: Welcome Sir/Madam
#
#   5. using *args for multiple values
#
#            def add_number(*number):
#               add = 0
#
#               for n in number:
#                   add = add+n
#
#               return add
#
#             add_number(1,2,3,4,5)
#
#              output: 15
#
#   6. using **kwargs for multiple keywords
#
#             def show_details(**detail):
#
#                 for k, v in detail.items():
#                     print(k, ":", v)
#
#             show_details(name="Aa", age=25)
#             output: name: Aa
#                     age: 25
#
# 4. What is the purpose of the 'return' statement in a Python function?
#   - The return statement in python is used to send a value back to where the function was called. If we donot use return function, function automatically return none. return value we can store in variable and print anywhere we want to print.
#
#          def add_number(a,b):
#              return a+b
#
#          value = add_number(2,4)
#          print(value)
#
# 5. What are iterators in Python and how do they differ from iterables?
#   - An iterators is an object that allows traversal through a countable number of values. Its gives one vlaue at a time using next() function
#   Iterables is a python object that can be looped over like list, tuple, string etc. it proives an interator when we use iter() function
#
#   Iterable - container of items that can be looped over
#   Iterator -  produces items one bye one from the iterable.
#
#   examples:
#        num = [10, 20, 30]
#        iterator = iter(num)
#
#        print(next(iterator))
#        print(next(iterator))
#        print(next(iterator))
#
#        output: 10
#                20
#                30
#
# 6. Explain the concept of generators in Python and how they are defined.
#   - A generator in python is a type of function that allows us to produce a sequence of values one at a time instead of generating and storing entire value in memory. when we use yield keyword in fucntion it becomes a generator function. Each time the function is called it pauses at yield and continues from the same point on the next call.
#
#          def squ(number):
#             for i in range(1,number+1):
#                yield i**2
#
#          res = squ(5)
#          print(next(res))
#          output: 1
#
#
# 7. What are the advantages of using generators over regular functions?
#   -  Generators use less memory because they yield one value at a time.
#      They generate values only when needed.
#      Faster for large data as results come immediately.
#      Easier to write than iterator classes becacuse using yield.
#      Useful for data pipelines, step-by-step processing.
#
# 8. What is a lambda function in Python and when is it typically used?
#   - A lamba function in python is a small, anonymous function that is defined using the 'lambda' keywords instead of 'def'. lamba function can only contain a single expressiorn. it is mainly used when you need a simple function for a short period of time
#   example:
#          sqr = lambda x: x**2
#          print(sqr(11)
#          output: 121
#
# 9. Explain the purpose and usage of the 'map()' function in Python.
#   - the map function is used to apply a givern function to every item in an iterable like list, tuple etc and return a new map object which can be converted into a list, tuple etc
#   examples:
#          nums = [1, 2, 3, 4]
#          result = map(lambda x: x**2, nums)
#          print(list(result))
#          Output: [1, 4, 9, 16]
#
# 10. What is the difference between 'map()', 'reduce()', and 'filter() functions in Python?
#   - the map function is used to apply a givene function to each item of an iterable adnd return a new map object wiht the reusle. The filter function is used to filter out elements from an iterable based on a condition. The reduce function from the functools is used to apply a sequential pairs of itmes in an iterable reducing it to a single cumulative value.
#
#           nums = [1, 2, 3, 4]
#           result = map(lambda x: x**2, nums)
#           print(list(result))
#           Output: [1, 4, 9, 16]
#
#           nums = [1, 2, 3, 4, 5, 6]
#           result = list(filter(lambda x: x % 2 == 0, nums))
#           print(result)
#           Output: [2, 4, 6]
#
#           from functools import reduce
#           nums = [1, 2, 3, 4]
#           result = reduce(lambda x, y: x * y, nums)
#           print(result)
#           Output: 24
#
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given list:[47,11,42,13];
#   - ![image.png](data:image/png;base64,...)

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def even_sum(numbers):
  total = 0
  for i in numbers:
    if(i%2==0):
      total = total+i

  return total

list1 = [2,3,4,6,9,8,6]

result = even_sum(list1)
print(result)
# Out:
# 26

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.

def reverse_str(string):
  return string[::-1]

str_1 = "pwskills"
result = reverse_str(str_1)
print(result)
# Out:
# sllikswp

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square_number(number):
  sqr = []
  for i in number:
    sqr.append(i**2)
  return sqr

list1 = [2,3,5,6,4,7,8]
res = square_number(list1)
print(res)
# Out:
# [4, 9, 25, 36, 16, 49, 64]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

def isprime(number):
  if number==1:
    return False
  if number==2:
    return True

  for i in range(2,number):
    if number%i==0:
       return False

    return True

num = 197
result = isprime(num)
if result == True:
  print(num, "is a prime number")
else:
  print(num, "is not a prime number")
# Out:
# 197 is a prime number

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

def fibonacci(num):
  first = 0
  second = 1
  list1 = []

  for i in range(num):
    list1.append(first)
    first,second = second, first+second

  return iter(list1)

res = fibonacci(8)
print(next(res))
print(next(res))
print(next(res))
print(next(res))
print(next(res))
print(next(res))
print(next(res))
print(next(res))
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent

def expo(n):
  for i in range(0,n+1):
    yield 2**i

res = expo(5)
res
next(res)
# Out:
# 1

# %%
next(res)
# Out:
# 2

# %%
next(res)
# Out:
# 4

# %%
next(res)
# Out:
# 8

# %%
next(res)
# Out:
# 16

# %%
next(res)
# Out:
# 32

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

li_tuples = [(3,1),(4,5),(6,3),(2,5)]

print(sorted(li_tuples, key=lambda x: x[1]))
# Out:
# [(3, 1), (6, 3), (4, 5), (2, 5)]

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

temp_celsius = [2,34,23,45,21]

temp_fahrenheit = list(map(lambda x: (x*9/5)+32, temp_celsius))
print(temp_fahrenheit)
# Out:
# [35.6, 93.2, 73.4, 113.0, 69.8]

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

str1 = "Python program uses"

result = list(filter(lambda x: x.lower() not in "aeiou ", str1))
print(result)
# Out:
# ['P', 'y', 't', 'h', 'n', 'p', 'r', 'g', 'r', 'm', 's', 's']

# %%
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:


# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €.

# Write a Python program using lambda and map.


orders = [
    # ["Order Number", "Book Title and Author", "Quantity", "Price Per Item" ]
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

final_orders = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))

print(final_orders)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
